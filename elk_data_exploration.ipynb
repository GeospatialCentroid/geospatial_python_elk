# %%
import folium
from folium.plugins import MarkerCluster, Draw
import geopandas as gpd # https://geopandas.org/en/stable/docs

# %%
location_file="data/ElkWinter08_09.csv"
location_df=gpd.read_file(location_file)

# %%
location_df.crs = 'epsg:4326'

# %%
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#       geometry
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 10480     None
# 10481     None
# 10482     None
# 10483     None
# 10484     None
#
# [10485 rows x 8 columns]

# %%
location_df = gpd.GeoDataFrame(
    location_df, geometry=gpd.points_from_xy(location_df.x, location_df.y)
)

# %%
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#                           geometry
# 0      POINT (-105.66458 40.36731)
# 1      POINT (-105.65654 40.35872)
# 2      POINT (-105.64652 40.41593)
# 3      POINT (-105.64488 40.41001)
# 4      POINT (-105.64453 40.41234)
# ...                            ...
# 10480  POINT (-105.52291 40.38842)
# 10481  POINT (-105.52240 40.38824)
# 10482  POINT (-105.52111 40.38768)
# 10483  POINT (-105.51854 40.38481)
# 10484  POINT (-105.50713 40.41242)
#
# [10485 rows x 8 columns]

# %%
# create map
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=5)
marker_cluster = MarkerCluster().add_to(m)

geo_df_list = [[location.xy[1][0], location.xy[0][0]] for location in location_df.geometry ]
# add a marker to the cluster, not the map
for location in geo_df_list:
    marker = folium.Marker(location=location)
    marker_cluster.add_child(marker)

draw = Draw(export=True)
draw.add_to(m)

m

# draw an rectangle to be used as and exclusion zone, 
# click the rectangle and copy the geojson into the next code cell
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96c441643dda23783b064c822d3157d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96c441643dda23783b064c822d3157d1&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96c441643dda23783b064c822d3157d1 = L.map(
#                 &quot;map_96c441643dda23783b064c822d3157d1&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_576b367b02a15f5e69be465779a50887 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_576b367b02a15f5e69be465779a50887.addTo(map_96c441643dda23783b064c822d3157d1);
#
#
#             var marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_77feab73246adac2adbc75224a2610da = L.marker(
#                 [40.367308, -105.664583],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_0addefd0acc19ad55625ff16f807080f = L.marker(
#                 [40.358716, -105.656541],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_2377d8ecbeb7e7a48fa86bc31e15d062 = L.marker(
#                 [40.415933, -105.646525],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_b60c00d26fac1dc8d941d48fe410c279 = L.marker(
#                 [40.410008, -105.644883],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_bf2117f98eee290473aded8867b6d19f = L.marker(
#                 [40.412341, -105.644525],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_d8fc17f16c4d32b6c9d1c6db912ddb9c = L.marker(
#                 [40.411333, -105.644233],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_9448f70652aa958ab52e1b0f7b06147d = L.marker(
#                 [40.411191, -105.644183],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_651a904d1f933f2f3004d58fb1f3566e = L.marker(
#                 [40.41115, -105.644],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_a31f1432e972f6ad501658d1cd731e71 = L.marker(
#                 [40.410891, -105.643533],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_8b0e80aa3a5f49f089b2520a2513abcc = L.marker(
#                 [40.4123, -105.643416],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_6b4762a153354c81656596604699afde = L.marker(
#                 [40.415616, -105.642575],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_962ee89641efbf58525c11f31116a9e0 = L.marker(
#                 [40.414458, -105.641991],
#                 {}
#             ).addTo(marker_cluster_5c4f2f9b7cb397c91d33ec7ce6b222bb);
#
#
#             var marker_eb8567578caed26eeef74a470fd16c03 = L.marker(

# %%
from shapely.geometry import shape
from shapely.geometry.polygon import Polygon
polygon_geojson={"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[-105.568657,40.357664],[-105.568657,40.369436],[-105.551834,40.369436],[-105.551834,40.357664],[-105.568657,40.357664]]]}}
polygon: Polygon = shape(polygon_geojson["geometry"])

filtered_locations = location_df[~location_df.within(polygon)]
print(len(location_df))
len(filtered_locations)
# Out:
# 10485
# 194

# %%
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf022e7a651671aedf3f30ea1a1095ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf022e7a651671aedf3f30ea1a1095ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf022e7a651671aedf3f30ea1a1095ac = L.map(
#                 &quot;map_bf022e7a651671aedf3f30ea1a1095ac&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18b197e48229be115995cbbf5e588832 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_18b197e48229be115995cbbf5e588832.addTo(map_bf022e7a651671aedf3f30ea1a1095ac);
#
#
#             var marker_cluster_192e29f59e6d0138b9659ea023879811 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_192e29f59e6d0138b9659ea023879811.addTo(map_bf022e7a651671aedf3f30ea1a1095ac);
#
#
#         function geo_json_bf19c98546147ef2bf711c451ebe110a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bf19c98546147ef2bf711c451ebe110a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bf19c98546147ef2bf711c451ebe110a_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_bf19c98546147ef2bf711c451ebe110a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_bf19c98546147ef2bf711c451ebe110a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bf19c98546147ef2bf711c451ebe110a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bf19c98546147ef2bf711c451ebe110a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bf19c98546147ef2bf711c451ebe110a = L.geoJson(null, {
#                 onEachFeature: geo_json_bf19c98546147ef2bf711c451ebe110a_onEachFeature,
#
#                 style: geo_json_bf19c98546147ef2bf711c451ebe110a_styler,
#                 pointToLayer: geo_json_bf19c98546147ef2bf711c451ebe110a_pointToLayer,
#         });
#
#         function geo_json_bf19c98546147ef2bf711c451ebe110a_add (data) {
#             geo_json_bf19c98546147ef2bf711c451ebe110a
#                 .addData(data);
#         }
#             geo_json_bf19c98546147ef2bf711c451ebe110a_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&qu

# %%
filtered_locations.to_csv("data/filtered_elk_locations.csv")

# %%
unique_col="CollarID"
filtered_locations[unique_col].unique()
# Out:
# array(['843COW', '856', '881'], dtype=object)

# %%
ids =['843COW', '856', '881']
colors =['blue','green','red']

m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)
marker_cluster = MarkerCluster().add_to(m)

for index, row in filtered_locations.iterrows():
    folium.CircleMarker(location=(row['y'],row['x']),
                        color=colors[ids.index(row[unique_col])],
                        radius=5,
                        fill=True,
                        popup=row[unique_col]
                        ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c387ab59f572689034fd85705f3f7bc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c387ab59f572689034fd85705f3f7bc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c387ab59f572689034fd85705f3f7bc7 = L.map(
#                 &quot;map_c387ab59f572689034fd85705f3f7bc7&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ec0fd67e74dc6b1229b59e434f1b14e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1ec0fd67e74dc6b1229b59e434f1b14e.addTo(map_c387ab59f572689034fd85705f3f7bc7);
#
#
#             var marker_cluster_6ab2a93668ef7ee0b5cf22ca1131a8fe = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_6ab2a93668ef7ee0b5cf22ca1131a8fe.addTo(map_c387ab59f572689034fd85705f3f7bc7);
#
#
#             var circle_marker_bd439fd2a3d0bfbcc0809c251e586750 = L.circleMarker(
#                 [40.367308, -105.664583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c387ab59f572689034fd85705f3f7bc7);
#
#
#         var popup_81288a2ffd0544d0efbdf732cc47e86b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d84fa199c414961ae6e5d7b798d28f42 = $(`&lt;div id=&quot;html_d84fa199c414961ae6e5d7b798d28f42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;843COW&lt;/div&gt;`)[0];
#                 popup_81288a2ffd0544d0efbdf732cc47e86b.setContent(html_d84fa199c414961ae6e5d7b798d28f42);
#
#
#
#         circle_marker_bd439fd2a3d0bfbcc0809c251e586750.bindPopup(popup_81288a2ffd0544d0efbdf732cc47e86b)
#         ;
#
#
#
#
#             var circle_marker_0cf0e14d051ce25d62baced6ae573618 = L.circleMarker(
#                 [40.358716, -105.656541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c387ab59f572689034fd85705f3f7bc7);
#
#
#         var popup_2cb0b2ea0889aeb0b6162f4f4871a666 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4961469610a2e03eec1a2c3ea7a21431 = $(`&lt;div id=&quot;html_4961469610a2e03eec1a2c3ea7a21431&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;843COW&lt;/div&gt;`)[0];
#                 popup_2cb0b2ea0889aeb0b6162f4f4871a666.setContent(html_4961469610a2e03eec1a2c3ea7a21431);
#
#
#
#         circle_marker_0cf0e14d051ce25d62baced6ae573618.bindPopup(popup_2cb0b2ea0889aeb0b6162f4f4871a666)
#         ;
#
#
#
#
#             var circle_marker_0db5029694d571d5653615b9b7ff275f = L.circleMarker(
#                 [40.415933, -105.646525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c387ab59f572689034fd85705f3f7bc7);
#
#
#         var popup_0af4f1d6a801160ee53e8b96cdffb75a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25c68562aaacaa3880a7555bd49f5abd = $(`&lt;div id=&quot;html_25c68562aaacaa3880a7555bd49f5abd&quot; st

# %%
animal_locations=filtered_locations[filtered_locations[unique_col]=='843COW']
len(animal_locations)
# Out:
# 168

# %%
import datetime

date_col="Date_MMDDY"

animal_locations_geojson={"features": []}
for index, row in animal_locations.iterrows():
    date1 = datetime.datetime.strptime(row[date_col], "%m/%d/%Y")
    date2 = date1#+datetime.timedelta(days=1)
    animal_locations_geojson["features"].append({"type":"Feature",
                                                 "properties":{"times": [date1.strftime("%Y-%m-%d"),date2.strftime("%Y-%m-%d")]},
                                   
                                     "geometry":{"type":"Point","coordinates":[row['x'],row['y']]}})
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)
# folium.GeoJson(animal_locations_geojson).add_to(m)

folium.plugins.TimestampedGeoJson(
    animal_locations_geojson,
    date_options="YYYY-MM-DD",
    period="P1D",
    duration="P1D",
    add_last_point=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7c2d62756fc1123f590f7467ab009cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7c2d62756fc1123f590f7467ab009cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7c2d62756fc1123f590f7467ab009cc = L.map(
#                 &quot;map_e7c2d62756fc1123f590f7467ab009cc&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1f6b40d7f85a72ecd4b9d04cb1071a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1f6b40d7f85a72ecd4b9d04cb1071a5.addTo(map_e7c2d62756fc1123f590f7467ab009cc);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD&quot;);
#                 }
#             });
#             map_e7c2d62756fc1123f590f7467ab009cc.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1D&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: true, &quot;loopButton&quot;: false, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: false}
#             );
#             map_e7c2d62756fc1123f590f7467ab009cc.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-03-05&quot;, &quot;2009-03-05&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.664583&quot;, &quot;40.367308&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-11-16&quot;, &quot;2008-11-16&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.656541&quot;, &quot;40.358716&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-03-28&quot;, &quot;2009-03-28&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.641483&quot;, &quot;40.373875&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-19&quot;, &quot;2008-12-19&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.640833&quot;, &quot;40.358466&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-21&quot;, &quot;2008-12-21&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.640383&quot;, &quot;40.3479&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-01-29&quot;, &quot;2009-01-29&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.631858&quot;, &quot;40.366358&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-11-25&quot;, &quot;2008-11-25&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.6249&quot;, &quot;40.347033&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-01&quot;, &quot;2008-12-01&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordin
