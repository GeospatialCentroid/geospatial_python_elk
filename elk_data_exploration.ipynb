# %% [markdown]
# The following jupyter notebook demonstrates how a point file containing elk locations can be explored using an interactive map.

# %%
import folium # to make interactive maps
from folium.plugins import MarkerCluster, Draw # to group points on map and draw shapes
import geopandas as gpd # to work with geospatial data -- https://geopandas.org/en/stable/docs

# %%
# Load the data
location_file="data/ElkWinter08_09.csv"
location_df=gpd.read_file(location_file)

# %%
# Assign the coordinate reference system
location_df.crs = 'epsg:4326'

# %%
# View the data
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#       geometry
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 10480     None
# 10481     None
# 10482     None
# 10483     None
# 10484     None
#
# [10485 rows x 8 columns]

# %%
# Create geometry values
location_df = gpd.GeoDataFrame(
    location_df, geometry=gpd.points_from_xy(location_df.x, location_df.y)
)

# %%
# View the data again
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#                           geometry
# 0      POINT (-105.66458 40.36731)
# 1      POINT (-105.65654 40.35872)
# 2      POINT (-105.64652 40.41593)
# 3      POINT (-105.64488 40.41001)
# 4      POINT (-105.64453 40.41234)
# ...                            ...
# 10480  POINT (-105.52291 40.38842)
# 10481  POINT (-105.52240 40.38824)
# 10482  POINT (-105.52111 40.38768)
# 10483  POINT (-105.51854 40.38481)
# 10484  POINT (-105.50713 40.41242)
#
# [10485 rows x 8 columns]

# %%
# Create map and show the data
# Get Rocky Mountain National Park coordinates - from https://www.google.com/maps
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=5)

# Create and add a marker cluster to the map
marker_cluster = MarkerCluster().add_to(m)

# Create a list of location coordinates
geo_df_list = [[location.xy[1][0], location.xy[0][0]] for location in location_df.geometry]

# Create a marker for each location and add them to the cluster
for location in geo_df_list:
    marker = folium.Marker(location=location)
    marker_cluster.add_child(marker)

# Create and add a drawing control to the map
draw = Draw(export=True)
draw.add_to(m)

# show the map
m

# Beacuse there appears to be a lot of test data, draw a rectangle to be used as an exclusion zone
# Click the rectangle and copy the geojson into the next code cell
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4738777e2aed4b139500f30ba67b092b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4738777e2aed4b139500f30ba67b092b&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4738777e2aed4b139500f30ba67b092b = L.map(
#                 &quot;map_4738777e2aed4b139500f30ba67b092b&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fe5ada40e95cc47798829ef4dbbb868 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4fe5ada40e95cc47798829ef4dbbb868.addTo(map_4738777e2aed4b139500f30ba67b092b);
#
#
#             var marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_429020594c0d872b3cfdc369273be60a = L.marker(
#                 [40.367308, -105.664583],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_bdd3e8e3f1fcd5c3bea20cac6ccf09c8 = L.marker(
#                 [40.358716, -105.656541],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_1e7131ca2c932911dca0f72d94d5b0fc = L.marker(
#                 [40.415933, -105.646525],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_6c3d95452da76c0e8cc210064fa67b21 = L.marker(
#                 [40.410008, -105.644883],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_5880a64e31b7bb4e0f58873af4367c92 = L.marker(
#                 [40.412341, -105.644525],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_e84006172ba7caa4c1dc53a90ee53e15 = L.marker(
#                 [40.411333, -105.644233],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_e4fa6ecc72e15e715b0c5a9a0393c161 = L.marker(
#                 [40.411191, -105.644183],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_ee6616bf95af0bf106b14e514afa62dc = L.marker(
#                 [40.41115, -105.644],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_7950bc8f9e1137a3742ae0f827275c66 = L.marker(
#                 [40.410891, -105.643533],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_6a19fdb77edd8b758f20bbacdd26336d = L.marker(
#                 [40.4123, -105.643416],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_b0371e38247a10cdf9d4510eba02d24d = L.marker(
#                 [40.415616, -105.642575],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_e79e79ac94ab7b0f75e87ad354376d65 = L.marker(
#                 [40.414458, -105.641991],
#                 {}
#             ).addTo(marker_cluster_29dc6071b33626fe5c8e94b0ef8e850b);
#
#
#             var marker_9d2803d1f6a4d30bcf6860940513bed9 = L.marker(

# %%
# Load in shaply shape and polygon packages to convert our geojson to a polygon
from shapely.geometry import shape
from shapely.geometry.polygon import Polygon

# Store the geojson from earlier and convert to a polygon
polygon_geojson={"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[-105.568657,40.357664],[-105.568657,40.369436],[-105.551834,40.369436],[-105.551834,40.357664],[-105.568657,40.357664]]]}}
polygon: Polygon = shape(polygon_geojson["geometry"])

# Exclude the data from within the polygon, storing it as a new filtered geodataframe
filtered_locations = location_df[~location_df.within(polygon)]

# Compare the number of locations before and after the filter
print(len(location_df))
len(filtered_locations)
# Out:
# 10485
# 194

# %%
# Create a map of the filtered locations

m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad156a1ee5583de98493af184661e381 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad156a1ee5583de98493af184661e381&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad156a1ee5583de98493af184661e381 = L.map(
#                 &quot;map_ad156a1ee5583de98493af184661e381&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db95b9215a5ec7b84b6b831056958a59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db95b9215a5ec7b84b6b831056958a59.addTo(map_ad156a1ee5583de98493af184661e381);
#
#
#         function geo_json_cb7f3a8780c235247fc42182912f6e91_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_cb7f3a8780c235247fc42182912f6e91_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_cb7f3a8780c235247fc42182912f6e91_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_cb7f3a8780c235247fc42182912f6e91_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_cb7f3a8780c235247fc42182912f6e91_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_cb7f3a8780c235247fc42182912f6e91.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_cb7f3a8780c235247fc42182912f6e91_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_cb7f3a8780c235247fc42182912f6e91 = L.geoJson(null, {
#                 onEachFeature: geo_json_cb7f3a8780c235247fc42182912f6e91_onEachFeature,
#
#                 style: geo_json_cb7f3a8780c235247fc42182912f6e91_styler,
#                 pointToLayer: geo_json_cb7f3a8780c235247fc42182912f6e91_pointToLayer,
#         });
#
#         function geo_json_cb7f3a8780c235247fc42182912f6e91_add (data) {
#             geo_json_cb7f3a8780c235247fc42182912f6e91
#                 .addData(data);
#         }
#             geo_json_cb7f3a8780c235247fc42182912f6e91_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;856&quot;, &quot;Date_MM

# %%
# Explore the data
filtered_locations.to_csv("data/filtered_elk_locations.csv")

# %% [markdown]
# ## Extra

# %%
# Get the number of unique tracking devices
unique_col="CollarID"
filtered_locations[unique_col].unique()
# Out:
# array(['843COW', '856', '881'], dtype=object)

# %%
# Create a map using different colors for each device
ids =['843COW', '856', '881']
colors =['blue','green','red']

m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)
marker_cluster = MarkerCluster().add_to(m)

for index, row in filtered_locations.iterrows():
    folium.CircleMarker(location=(row['y'],row['x']),
                        color=colors[ids.index(row[unique_col])],
                        radius=5,
                        fill=True,
                        popup=row[unique_col]
                        ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f600191f5884dd35466827a47ae670dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f600191f5884dd35466827a47ae670dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f600191f5884dd35466827a47ae670dd = L.map(
#                 &quot;map_f600191f5884dd35466827a47ae670dd&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_923a2a4ec3a95530c536e0f825f33acd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_923a2a4ec3a95530c536e0f825f33acd.addTo(map_f600191f5884dd35466827a47ae670dd);
#
#
#             var marker_cluster_2fb09ec6fda27d165cd1b22983089688 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_2fb09ec6fda27d165cd1b22983089688.addTo(map_f600191f5884dd35466827a47ae670dd);
#
#
#             var circle_marker_b4d6cdbc14ee321b0b38731e8447a4b1 = L.circleMarker(
#                 [40.367308, -105.664583],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f600191f5884dd35466827a47ae670dd);
#
#
#         var popup_93f767f1be684b7306e73843167bfc77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0123f6244d5a175577f8b8a39662e168 = $(`&lt;div id=&quot;html_0123f6244d5a175577f8b8a39662e168&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;843COW&lt;/div&gt;`)[0];
#                 popup_93f767f1be684b7306e73843167bfc77.setContent(html_0123f6244d5a175577f8b8a39662e168);
#
#
#
#         circle_marker_b4d6cdbc14ee321b0b38731e8447a4b1.bindPopup(popup_93f767f1be684b7306e73843167bfc77)
#         ;
#
#
#
#
#             var circle_marker_e1f3107fac427d6321995b8f567db050 = L.circleMarker(
#                 [40.358716, -105.656541],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f600191f5884dd35466827a47ae670dd);
#
#
#         var popup_a2ee5b3d618004bd2e739d843901c079 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fde9cd04d80b46e362875bdcfbbd0814 = $(`&lt;div id=&quot;html_fde9cd04d80b46e362875bdcfbbd0814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;843COW&lt;/div&gt;`)[0];
#                 popup_a2ee5b3d618004bd2e739d843901c079.setContent(html_fde9cd04d80b46e362875bdcfbbd0814);
#
#
#
#         circle_marker_e1f3107fac427d6321995b8f567db050.bindPopup(popup_a2ee5b3d618004bd2e739d843901c079)
#         ;
#
#
#
#
#             var circle_marker_90dbf9e5c007c63f4b250a503851b065 = L.circleMarker(
#                 [40.415933, -105.646525],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f600191f5884dd35466827a47ae670dd);
#
#
#         var popup_7b72c0e771c6f4db8d00f90531dc7562 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9af0f72ba586c3ff6a598cc12a52d24 = $(`&lt;div id=&quot;html_a9af0f72ba586c3ff6a598cc12a52d24&quot; st

# %%
# Separate one device
animal_locations=filtered_locations[filtered_locations[unique_col]=='843COW']
len(animal_locations)
# Out:
# 168

# %%
# Animate the locations of a specific device over time

import datetime

date_col="Date_MMDDY"

animal_locations_geojson={"features": []}
for index, row in animal_locations.iterrows():
    date1 = datetime.datetime.strptime(row[date_col], "%m/%d/%Y")
    date2 = date1#+datetime.timedelta(days=1)
    animal_locations_geojson["features"].append({"type":"Feature",
                                                 "properties":{"times": [date1.strftime("%Y-%m-%d"),date2.strftime("%Y-%m-%d")]},
                                   
                                     "geometry":{"type":"Point","coordinates":[row['x'],row['y']]}})
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)
# folium.GeoJson(animal_locations_geojson).add_to(m)

folium.plugins.TimestampedGeoJson(
    animal_locations_geojson,
    date_options="YYYY-MM-DD",
    period="P1D",
    duration="P1D",
    add_last_point=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e4d866a25b7bafc5fe1642596525fbe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e4d866a25b7bafc5fe1642596525fbe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e4d866a25b7bafc5fe1642596525fbe = L.map(
#                 &quot;map_1e4d866a25b7bafc5fe1642596525fbe&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d11b101deb00f7dd966a05f691724550 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d11b101deb00f7dd966a05f691724550.addTo(map_1e4d866a25b7bafc5fe1642596525fbe);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD&quot;);
#                 }
#             });
#             map_1e4d866a25b7bafc5fe1642596525fbe.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1D&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {&quot;autoPlay&quot;: true, &quot;loopButton&quot;: false, &quot;maxSpeed&quot;: 10, &quot;minSpeed&quot;: 0.1, &quot;playerOptions&quot;: {&quot;loop&quot;: true, &quot;startOver&quot;: true, &quot;transitionTime&quot;: 200}, &quot;position&quot;: &quot;bottomleft&quot;, &quot;speedSlider&quot;: true, &quot;timeSliderDragUpdate&quot;: false}
#             );
#             map_1e4d866a25b7bafc5fe1642596525fbe.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-03-05&quot;, &quot;2009-03-05&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.664583&quot;, &quot;40.367308&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-11-16&quot;, &quot;2008-11-16&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.656541&quot;, &quot;40.358716&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-03-28&quot;, &quot;2009-03-28&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.641483&quot;, &quot;40.373875&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-19&quot;, &quot;2008-12-19&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.640833&quot;, &quot;40.358466&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-21&quot;, &quot;2008-12-21&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.640383&quot;, &quot;40.3479&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2009-01-29&quot;, &quot;2009-01-29&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.631858&quot;, &quot;40.366358&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-11-25&quot;, &quot;2008-11-25&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [&quot;-105.6249&quot;, &quot;40.347033&quot;]}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;properties&quot;: {&quot;times&quot;: [&quot;2008-12-01&quot;, &quot;2008-12-01&quot;]}, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordin
