# %% [markdown]
# The following jupyter notebook demonstrates how a point file containing elk locations can be explored using an interactive map.

# %%
import geopandas as gpd # to work with geospatial data -- https://geopandas.org/en/stable/docs

# %%
# Load the data
location_file="data/ElkWinter08_09.csv"
location_df=gpd.read_file(location_file)

# %%
# Assign the coordinate reference system
location_df.crs = 'epsg:4326'

# %%
# View the data
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#       geometry
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 10480     None
# 10481     None
# 10482     None
# 10483     None
# 10484     None
#
# [10485 rows x 8 columns]

# %%
# Create geometry values
location_df = gpd.GeoDataFrame(
    location_df, geometry=gpd.points_from_xy(location_df.x, location_df.y)
)

# %%
# View the data again
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#                           geometry
# 0      POINT (-105.66458 40.36731)
# 1      POINT (-105.65654 40.35872)
# 2      POINT (-105.64652 40.41593)
# 3      POINT (-105.64488 40.41001)
# 4      POINT (-105.64453 40.41234)
# ...                            ...
# 10480  POINT (-105.52291 40.38842)
# 10481  POINT (-105.52240 40.38824)
# 10482  POINT (-105.52111 40.38768)
# 10483  POINT (-105.51854 40.38481)
# 10484  POINT (-105.50713 40.41242)
#
# [10485 rows x 8 columns]

# %%
import folium # to make interactive maps
from folium.plugins import MarkerCluster, Draw # to group points on map and draw shapes

# Create map and show the data
# Get Rocky Mountain National Park coordinates - from https://www.google.com/maps
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=5)

# Create and add a marker cluster to the map
marker_cluster = MarkerCluster().add_to(m)

# Create a list of location coordinates
geo_df_list = [[location.xy[1][0], location.xy[0][0]] for location in location_df.geometry]

# Create a marker for each location and add them to the cluster
for location in geo_df_list:
    marker = folium.Marker(location=location)
    marker_cluster.add_child(marker)

# Create and add a drawing control to the map
draw = Draw(export=True)
draw.add_to(m)

# show the map
m

# Beacuse there appears to be a lot of test data, draw a rectangle to be used as an exclusion zone
# Click the rectangle and copy the geojson into the next code cell
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acfd37845643856051067e70694a9023 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acfd37845643856051067e70694a9023&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acfd37845643856051067e70694a9023 = L.map(
#                 &quot;map_acfd37845643856051067e70694a9023&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b324a5c35ae3f7118bc0bb91d3e68a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5b324a5c35ae3f7118bc0bb91d3e68a3.addTo(map_acfd37845643856051067e70694a9023);
#
#
#             var marker_cluster_5ab7d49d69d66fd30ced69735f40373a = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_f0adf61152dd0fd55caf859d4a3b15f3 = L.marker(
#                 [40.367308, -105.664583],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_4dec5de8c1137ba3f1f0f12ffcaa371f = L.marker(
#                 [40.358716, -105.656541],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_ee2861a8d54880cc903bb46990c15fd2 = L.marker(
#                 [40.415933, -105.646525],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_618ae59563c4c5ae8877be87a008030a = L.marker(
#                 [40.410008, -105.644883],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_51c36da45e5f2ff145eb921bc5a6b265 = L.marker(
#                 [40.412341, -105.644525],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_38462a8b3592511dc82c309a4fe481bf = L.marker(
#                 [40.411333, -105.644233],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_4ab52f80a58fdc2d7703e3a495f9bbba = L.marker(
#                 [40.411191, -105.644183],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_470bfc578e5f295de5d2dbde44c1d405 = L.marker(
#                 [40.41115, -105.644],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_eec020f99994689b82d25298d9ccbd4a = L.marker(
#                 [40.410891, -105.643533],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_699b1446711931f66dfafb17373444f6 = L.marker(
#                 [40.4123, -105.643416],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_0053b13856c8912ea966276473f5b932 = L.marker(
#                 [40.415616, -105.642575],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_faa6a058af88255e16b0f693ea532ab4 = L.marker(
#                 [40.414458, -105.641991],
#                 {}
#             ).addTo(marker_cluster_5ab7d49d69d66fd30ced69735f40373a);
#
#
#             var marker_4f1af279164a8674e1faa673c2dfa17d = L.marker(

# %%
# Load in shaply shape and polygon packages to convert our geojson to a polygon
from shapely.geometry import shape
from shapely.geometry.polygon import Polygon

# Store the geojson from earlier and convert to a polygon
polygon_geojson={"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[-105.568657,40.357664],[-105.568657,40.369436],[-105.551834,40.369436],[-105.551834,40.357664],[-105.568657,40.357664]]]}}
polygon: Polygon = shape(polygon_geojson["geometry"])

# Exclude the data from within the polygon, storing it as a new filtered geodataframe
filtered_locations = location_df[~location_df.within(polygon)]

# Compare the number of locations before and after the filter
print(len(location_df))
len(filtered_locations)
# Out:
# 10485
# 194

# %%
# Create a map of the filtered locations

m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_683c68dbf676ff52c4dbde8be8435034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_683c68dbf676ff52c4dbde8be8435034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_683c68dbf676ff52c4dbde8be8435034 = L.map(
#                 &quot;map_683c68dbf676ff52c4dbde8be8435034&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_820d755f2b80b3037923604cd67cb6e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_820d755f2b80b3037923604cd67cb6e0.addTo(map_683c68dbf676ff52c4dbde8be8435034);
#
#
#         function geo_json_6b94a59fc561535093ee049dbbfc3749_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6b94a59fc561535093ee049dbbfc3749_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6b94a59fc561535093ee049dbbfc3749_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_6b94a59fc561535093ee049dbbfc3749_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_6b94a59fc561535093ee049dbbfc3749_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_6b94a59fc561535093ee049dbbfc3749.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6b94a59fc561535093ee049dbbfc3749_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6b94a59fc561535093ee049dbbfc3749 = L.geoJson(null, {
#                 onEachFeature: geo_json_6b94a59fc561535093ee049dbbfc3749_onEachFeature,
#
#                 style: geo_json_6b94a59fc561535093ee049dbbfc3749_styler,
#                 pointToLayer: geo_json_6b94a59fc561535093ee049dbbfc3749_pointToLayer,
#         });
#
#         function geo_json_6b94a59fc561535093ee049dbbfc3749_add (data) {
#             geo_json_6b94a59fc561535093ee049dbbfc3749
#                 .addData(data);
#         }
#             geo_json_6b94a59fc561535093ee049dbbfc3749_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;856&quot;, &quot;Date_MM

# %%
# Export the data
filtered_locations.to_csv("data/filtered_elk_locations.csv")

# %% [markdown]
# ## Load in other data

# %%
## Get the elevation data
'''
go to https://planetarycomputer.microsoft.com/catalog
select "DEM" from the side nav and select "Copernicus DEM GLO-30"
copy the STAC Collection API URL e.g https://planetarycomputer.microsoft.com/api/stac/v1/collections/cop-dem-glo-30
and remove everything after "/collections/cop-dem-glo-30"

Note this standard uses Cloud Optimized GeoTiffs (COGS) 
which allow server-side clipping and overview images to speed
'''

api_url="https://planetarycomputer.microsoft.com/api/stac/v1"

from pystac_client import Client
import planetary_computer

client = Client.open(api_url,modifier=planetary_computer.sign_inplace)

# %%
# get elevation data continued
'''
Take the collection name from the API URL

'''
collection = 'cop-dem-glo-30'

# Access serach collection fror data around a point
# Load the shapely Point class to create a Point object
from shapely.geometry import Point

# Get Rocky Mountain National Park coordinates - from https://www.google.com/maps
# right click location, copy lat(y) and lng(x), and flip to conform to x,y
point = Point(-105.68988068298488, 40.384733209948294)  

# search the catalog
search = client.search(
    collections=[collection],
    intersects=point,
    max_items=10,
)
print(len(search.item_collection()))
# Out:
# 1

# %%
# get the first (and only) asset from the search
items=search.item_collection()
signed_asset = planetary_computer.sign(items[0].assets["data"])

# %%
# Create a tile layer since most browsers don't show Tiff files

from localtileserver import TileClient, get_folium_tile_layer # to visualize the geotif 
elevation_file=signed_asset.href
elevation_tiles = TileClient(elevation_file) # create tiles client
elevation_layer = get_folium_tile_layer(elevation_tiles, name='elevation') # create elevation tile layer

# %%
# create a map with the elevation data and elk locations
m = folium.Map([point.y,point.x], zoom_start = 10)
elevation_layer.add_to(m)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7315309fce1d25cf66b5402dd3605ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7315309fce1d25cf66b5402dd3605ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7315309fce1d25cf66b5402dd3605ad = L.map(
#                 &quot;map_e7315309fce1d25cf66b5402dd3605ad&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_880915201e777640ebc74de0c5be22b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_880915201e777640ebc74de0c5be22b1.addTo(map_e7315309fce1d25cf66b5402dd3605ad);
#
#
#             var tile_layer_a7704c3af925ea98d5f83088986722d6 = L.tileLayer(
#                 &quot;http://127.0.0.1:59278/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fvsicurl%3Furl%3Dhttps%253A%252F%252Felevationeuwest.blob.core.windows.net%252Fcopernicus-dem%252FCOP30_hh%252FCopernicus_DSM_COG_10_N40_00_W106_00_DEM.tif%253Fst%253D2024-02-26T22%25253A55%25253A20Z%2526se%253D2024-02-27T23%25253A40%25253A20Z%2526sp%253Drl%2526sv%253D2021-06-08%2526sr%253Dc%2526skoid%253Dc85c15d6-d1ae-42d4-af60-e2ca0f81359b%2526sktid%253D72f988bf-86f1-41af-91ab-2d7cd011db47%2526skt%253D2024-02-26T18%25253A45%25253A28Z%2526ske%253D2024-03-04T18%25253A45%25253A28Z%2526sks%253Db%2526skv%253D2021-06-08%2526sig%253DDrqO5tCWiZgmIkCfmq2UcFucSMbyyMI3OjTvSjOtvFM%25253D%26use_head%3Dno%26list_dir%3Dno&quot;,
#                 {&quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a7704c3af925ea98d5f83088986722d6.addTo(map_e7315309fce1d25cf66b5402dd3605ad);
#
#
#         function geo_json_9fc134dd93f4a17d2614b5af919c04fe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9fc134dd93f4a17d2614b5af919c04fe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9fc134dd93f4a17d2614b5af919c04fe_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_9fc134dd93f4a17d2614b5af919c04fe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_9fc134dd93f4a17d2614b5af919c04fe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_9fc134dd93f4a17d2614b5af919c04fe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9fc134dd93f4a17d2614b5af919c04fe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9fc134dd93f4a17d2614b5af919c04fe = L.geoJson(null, {
#                 onEachFeature: geo_json_9fc134dd93f4a17d2614b5af919c04fe_onEachFeature,
#
#                 style: geo_json_9fc134dd93f4a17d2614b5af919c04fe_styler,
#                 pointToLayer: geo_json_9fc134dd93f4a17d2614b5af919c04fe_pointToLayer,
#         });
#
#         function geo_json_9fc134dd93f4a17d2614b5af919c04fe_add (data) {
#             geo_json_9fc134dd93f4a17d2614b5af919c04fe
#                 .addData(data);
#         }
#             geo_json_9fc134dd93f4a17d2614b5af919c04fe_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -10

# %%
# add elevation information to each row

#create raster layer for sampling
src = rasterio.open(elevation_file)

# create a list of coordinates for sampling
coord_list = [(x, y) for x, y in zip(filtered_locations['geometry'].x, filtered_locations['geometry'].y)]
# # save the samples back to the dataframe, and choose the first value
filtered_locations["elevation"] = [x[0] for x in src.sample(coord_list)]
filtered_locations.head()
# Out:
#   OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0   146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1   146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2   146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3    68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4   146812      856   11/7/2008         0     305  40.412341  -105.644525
#
#                       geometry    elevation
# 0  POINT (-105.66458 40.36731)  3315.504150
# 1  POINT (-105.65654 40.35872)  2984.461426
# 2  POINT (-105.64652 40.41593)  2801.393799
# 3  POINT (-105.64488 40.41001)  2606.151855
# 4  POINT (-105.64453 40.41234)  2633.158691

# %%
# Load in the park boundary data (Format GeoJSON)
import json
park_file="data/Rocky_Mountain_National_Park_-_Boundary_Polygon.geojson"
with open(park_file, 'r') as f:
    park_data = json.load(f)

# %%
# create a map with the boundary and elk locations
m = folium.Map([point.y,point.x], zoom_start = 10)

filtered_locations.explore(m=m, marker_type="marker")

folium.GeoJson(park_data,
    style_function=lambda feature:
        { 'color': 'red','opacity': 1, 'dashArray': '9', 'fillOpacity': 0.2, 'weight': 2},
        name="RMNP park boundary"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_869a47fc77fca7e3d8f576518d99c45d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_869a47fc77fca7e3d8f576518d99c45d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_869a47fc77fca7e3d8f576518d99c45d = L.map(
#                 &quot;map_869a47fc77fca7e3d8f576518d99c45d&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8249bf2fc8dbf04e052957bc7e94830d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8249bf2fc8dbf04e052957bc7e94830d.addTo(map_869a47fc77fca7e3d8f576518d99c45d);
#
#
#         function geo_json_b0e925f59a4fac6920766bb3838f1ab4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b0e925f59a4fac6920766bb3838f1ab4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b0e925f59a4fac6920766bb3838f1ab4_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_b0e925f59a4fac6920766bb3838f1ab4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_b0e925f59a4fac6920766bb3838f1ab4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_b0e925f59a4fac6920766bb3838f1ab4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b0e925f59a4fac6920766bb3838f1ab4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b0e925f59a4fac6920766bb3838f1ab4 = L.geoJson(null, {
#                 onEachFeature: geo_json_b0e925f59a4fac6920766bb3838f1ab4_onEachFeature,
#
#                 style: geo_json_b0e925f59a4fac6920766bb3838f1ab4_styler,
#                 pointToLayer: geo_json_b0e925f59a4fac6920766bb3838f1ab4_pointToLayer,
#         });
#
#         function geo_json_b0e925f59a4fac6920766bb3838f1ab4_add (data) {
#             geo_json_b0e925f59a4fac6920766bb3838f1ab4
#                 .addData(data);
#         }
#             geo_json_b0e925f59a4fac6920766bb3838f1ab4_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;856&quot;, &quot;Date_MM

# %%
# Check if locations are in the park polygon

park_polygon: Polygon = shape(park_data["features"][0]["geometry"])

filtered_locations["within_park"] = ""
for index, row in filtered_locations.iterrows():
    print(row['geometry'])
    marker=Point(row['geometry'].x,row['geometry'].y)
    within=marker.within(park_polygon)
    # row['within_park']=within
    filtered_locations.loc[index, 'within_park'] = within
# Out:
# POINT (-105.664583 40.367308)
# POINT (-105.656541 40.358716)
# POINT (-105.646525 40.415933)
# POINT (-105.644883 40.410008)
# POINT (-105.644525 40.412341)
# POINT (-105.644233 40.411333)
# POINT (-105.644183 40.411191)
# POINT (-105.644 40.41115)
# POINT (-105.643533 40.410891)
# POINT (-105.643416 40.4123)
# POINT (-105.642575 40.415616)
# POINT (-105.641991 40.414458)
# POINT (-105.641483 40.373875)
# POINT (-105.640833 40.358466)
# POINT (-105.640383 40.3479)
# POINT (-105.640366 40.410191)
# POINT (-105.639216 40.409691)
