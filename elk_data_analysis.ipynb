# %% [markdown]
# The following jupyter notebook demonstrates how a point file containing elk locations can be explored using an interactive map and enriched with other sources of data.

# %%
import geopandas as gpd # to work with geospatial data -- https://geopandas.org/en/stable/docs

# %%
# Load the data
location_file="data/ElkWinter08_09.csv"
location_df=gpd.read_file(location_file)

# %%
# Assign the coordinate reference system
location_df.crs = 'epsg:4326'

# %%
# View the data
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#       geometry
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 10480     None
# 10481     None
# 10482     None
# 10483     None
# 10484     None
#
# [10485 rows x 8 columns]

# %%
# Create geometry values
location_df = gpd.GeoDataFrame(
    location_df, geometry=gpd.points_from_xy(location_df.x, location_df.y)
)

# %%
# View the data again
location_df
# Out:
#       OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0       146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1       146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2       146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3        68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4       146812      856   11/7/2008         0     305  40.412341  -105.644525
# ...        ...      ...         ...       ...     ...        ...          ...
# 10480   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 10481   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 10482   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 10483    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 10484    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#                           geometry
# 0      POINT (-105.66458 40.36731)
# 1      POINT (-105.65654 40.35872)
# 2      POINT (-105.64652 40.41593)
# 3      POINT (-105.64488 40.41001)
# 4      POINT (-105.64453 40.41234)
# ...                            ...
# 10480  POINT (-105.52291 40.38842)
# 10481  POINT (-105.52240 40.38824)
# 10482  POINT (-105.52111 40.38768)
# 10483  POINT (-105.51854 40.38481)
# 10484  POINT (-105.50713 40.41242)
#
# [10485 rows x 8 columns]

# %%
import folium # to make interactive maps
from folium.plugins import MarkerCluster, Draw # to group points on map and draw shapes

# Create map and show the data
# Get Rocky Mountain National Park coordinates - from https://www.google.com/maps
m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=5)

# Create and add a marker cluster to the map
marker_cluster = MarkerCluster().add_to(m)

# Create a list of location coordinates
geo_df_list = [[location.xy[1][0], location.xy[0][0]] for location in location_df.geometry]

# Create a marker for each location and add them to the cluster
for location in geo_df_list:
    marker = folium.Marker(location=location)
    marker_cluster.add_child(marker)

# Create and add a drawing control to the map
draw = Draw(export=True)
draw.add_to(m)

# show the map
m

# Beacuse there appears to be a lot of test data, draw a rectangle to be used as an exclusion zone
# Click the rectangle and copy the geojson into the next code cell
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a65b3b59ba8fef37f7b9f7d83a35461 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a65b3b59ba8fef37f7b9f7d83a35461&quot; &gt;&lt;/div&gt;
#
#     &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a65b3b59ba8fef37f7b9f7d83a35461 = L.map(
#                 &quot;map_9a65b3b59ba8fef37f7b9f7d83a35461&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d0c9463be275ff892d64c2ae6656dcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d0c9463be275ff892d64c2ae6656dcd.addTo(map_9a65b3b59ba8fef37f7b9f7d83a35461);
#
#
#             var marker_cluster_75a22d0665e67a91dc639d05b57b5d2d = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_4579529e7673e4c0239ab84cebcb60c7 = L.marker(
#                 [40.367308, -105.664583],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_6e17861f9daa81750ffc04738ddd5282 = L.marker(
#                 [40.358716, -105.656541],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_b5cc500d50badeabccaa9ba9761f235a = L.marker(
#                 [40.415933, -105.646525],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_baa6c0ec5d1d3bcd33c0a5e7a990c3cf = L.marker(
#                 [40.410008, -105.644883],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_e20d2246cff665605fd9b22c15b21a37 = L.marker(
#                 [40.412341, -105.644525],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_95d4b9fac8a52593f44410dca59bb6a3 = L.marker(
#                 [40.411333, -105.644233],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_9b71a935609dad9ea032afcfddd8b480 = L.marker(
#                 [40.411191, -105.644183],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_ca9eaaaf80b6d7ae6bf9adb96a0fc2ed = L.marker(
#                 [40.41115, -105.644],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_1ced29e591958490491d6cfb26cfde35 = L.marker(
#                 [40.410891, -105.643533],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_932aef6e2859e6c587bf8788a5084880 = L.marker(
#                 [40.4123, -105.643416],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_3e50d9471e5172f36464840288a0b38e = L.marker(
#                 [40.415616, -105.642575],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_90d0e4d54481f7947f22563d3c87884c = L.marker(
#                 [40.414458, -105.641991],
#                 {}
#             ).addTo(marker_cluster_75a22d0665e67a91dc639d05b57b5d2d);
#
#
#             var marker_219f75c60291f93daeb90a94c7996a15 = L.marker(

# %%
# Load in shaply shape and polygon packages to convert our geojson to a polygon
from shapely.geometry import shape
from shapely.geometry.polygon import Polygon

# Store the geojson from earlier and convert to a polygon
polygon_geojson={"type":"Feature","properties":{},"geometry":{"type":"Polygon","coordinates":[[[-105.568657,40.357664],[-105.568657,40.369436],[-105.551834,40.369436],[-105.551834,40.357664],[-105.568657,40.357664]]]}}
polygon: Polygon = shape(polygon_geojson["geometry"])

# Exclude the data from within the polygon, storing it as a new filtered geodataframe
filtered_locations = location_df[~location_df.within(polygon)]

# Compare the number of locations before and after the filter
print(len(location_df))
len(filtered_locations)
# Out:
# 10485
# 194

# %%
# Create a map of the filtered locations

m = folium.Map(location=[40.384733209948294,-105.68988068298488,], zoom_start=11)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5924442bfb360eb50102f5421416d2a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5924442bfb360eb50102f5421416d2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5924442bfb360eb50102f5421416d2a = L.map(
#                 &quot;map_d5924442bfb360eb50102f5421416d2a&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c72020bfd4c391117eab0ee4af0a00c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3c72020bfd4c391117eab0ee4af0a00c.addTo(map_d5924442bfb360eb50102f5421416d2a);
#
#
#         function geo_json_fefaa6902020a0a9645f7c72de4fcbde_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fefaa6902020a0a9645f7c72de4fcbde_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fefaa6902020a0a9645f7c72de4fcbde_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_fefaa6902020a0a9645f7c72de4fcbde_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_fefaa6902020a0a9645f7c72de4fcbde_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_fefaa6902020a0a9645f7c72de4fcbde.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fefaa6902020a0a9645f7c72de4fcbde_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fefaa6902020a0a9645f7c72de4fcbde = L.geoJson(null, {
#                 onEachFeature: geo_json_fefaa6902020a0a9645f7c72de4fcbde_onEachFeature,
#
#                 style: geo_json_fefaa6902020a0a9645f7c72de4fcbde_styler,
#                 pointToLayer: geo_json_fefaa6902020a0a9645f7c72de4fcbde_pointToLayer,
#         });
#
#         function geo_json_fefaa6902020a0a9645f7c72de4fcbde_add (data) {
#             geo_json_fefaa6902020a0a9645f7c72de4fcbde
#                 .addData(data);
#         }
#             geo_json_fefaa6902020a0a9645f7c72de4fcbde_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;856&quot;, &quot;Date_MM

# %%
# Export the data
exported_file="data/filtered_elk_locations.csv"
filtered_locations.to_csv(exported_file, index=False)

# %%
filtered_locations=gpd.read_file(exported_file, ignore_geometry=True)


filtered_locations = gpd.GeoDataFrame(
    filtered_locations, geometry=gpd.points_from_xy(filtered_locations.x, filtered_locations.y)
)
filtered_locations
# Out:
#     OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0     146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1     146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2     146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3      68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4     146812      856   11/7/2008         0     305  40.412341  -105.644525
# ..       ...      ...         ...       ...     ...        ...          ...
# 189   146823      856   11/8/2008         0      65  40.388416  -105.522908
# 190   146821      856   11/8/2008       2.3     220  40.388241    -105.5224
# 191   146822      856   11/8/2008         0     155  40.387675  -105.521108
# 192    68072      881   11/8/2008         0     315  40.384808  -105.518541
# 193    67981      881   11/2/2008        15      50  40.412425  -105.507125
#
#                         geometry
# 0    POINT (-105.66458 40.36731)
# 1    POINT (-105.65654 40.35872)
# 2    POINT (-105.64652 40.41593)
# 3    POINT (-105.64488 40.41001)
# 4    POINT (-105.64453 40.41234)
# ..                           ...
# 189  POINT (-105.52291 40.38842)
# 190  POINT (-105.52240 40.38824)
# 191  POINT (-105.52111 40.38768)
# 192  POINT (-105.51854 40.38481)
# 193  POINT (-105.50713 40.41242)
#
# [194 rows x 8 columns]

# %% [markdown]
# ## Load in other data for enrichment

# %%
## Get the elevation data
'''
go to https://planetarycomputer.microsoft.com/catalog
select "DEM" from the side nav and select "Copernicus DEM GLO-30"
copy the STAC Collection API URL e.g https://planetarycomputer.microsoft.com/api/stac/v1/collections/cop-dem-glo-30
and remove everything after "/collections/cop-dem-glo-30"

Note this standard uses Cloud Optimized GeoTiffs (COGS) 
which allow server-side clipping and overview images to speed
'''

api_url="https://planetarycomputer.microsoft.com/api/stac/v1"

from pystac_client import Client
import planetary_computer

client = Client.open(api_url,modifier=planetary_computer.sign_inplace)

# %%
# get elevation data continued
'''
Take the collection name from the API URL

'''
collection = 'cop-dem-glo-30'

# Access serach collection fror data around a point
# Load the shapely Point class to create a Point object
from shapely.geometry import Point

# Get Rocky Mountain National Park coordinates - from https://www.google.com/maps
# right click location, copy lat(y) and lng(x), and flip to conform to x,y
point = Point(-105.68988068298488, 40.384733209948294)  

# search the catalog
search = client.search(
    collections=[collection],
    intersects=point,
    max_items=10,
)
print(len(search.item_collection()))
# Out:
# 1

# %%
# get the first (and only) asset from the search
items=search.item_collection()
signed_asset = planetary_computer.sign(items[0].assets["data"])

# %%
# Create a tile layer since most browsers don't show Tiff files

from localtileserver import TileClient, get_folium_tile_layer # to visualize the geotif 
elevation_file=signed_asset.href
elevation_tiles = TileClient(elevation_file) # create tiles client
elevation_layer = get_folium_tile_layer(elevation_tiles, name='elevation') # create elevation tile layer

# %%
# create a map with the elevation data and elk locations
m = folium.Map([point.y,point.x], zoom_start = 10)
elevation_layer.add_to(m)

filtered_locations.explore(m=m, marker_type="marker")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b9ab1557c26a692f8909fb73d2ddfcf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b9ab1557c26a692f8909fb73d2ddfcf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b9ab1557c26a692f8909fb73d2ddfcf = L.map(
#                 &quot;map_2b9ab1557c26a692f8909fb73d2ddfcf&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4cd9a6e85836d6ea7deec79596e14ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a4cd9a6e85836d6ea7deec79596e14ea.addTo(map_2b9ab1557c26a692f8909fb73d2ddfcf);
#
#
#             var tile_layer_79004ff892fb634039574de525b69e50 = L.tileLayer(
#                 &quot;http://127.0.0.1:57104/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fvsicurl%3Furl%3Dhttps%253A%252F%252Felevationeuwest.blob.core.windows.net%252Fcopernicus-dem%252FCOP30_hh%252FCopernicus_DSM_COG_10_N40_00_W106_00_DEM.tif%253Fst%253D2024-02-27T16%25253A50%25253A46Z%2526se%253D2024-02-28T17%25253A35%25253A46Z%2526sp%253Drl%2526sv%253D2021-06-08%2526sr%253Dc%2526skoid%253Dc85c15d6-d1ae-42d4-af60-e2ca0f81359b%2526sktid%253D72f988bf-86f1-41af-91ab-2d7cd011db47%2526skt%253D2024-02-28T14%25253A02%25253A31Z%2526ske%253D2024-03-06T14%25253A02%25253A31Z%2526sks%253Db%2526skv%253D2021-06-08%2526sig%253DT17qVHuuMjW%25252B1N0siNadIgHMCF1cOuwsC%25252B%252F%252FRKm1J84%25253D%26use_head%3Dno%26list_dir%3Dno&quot;,
#                 {&quot;attribution&quot;: &quot;Raster file served by \u003ca href=\u0027https://github.com/banesullivan/localtileserver\u0027 target=\u0027_blank\u0027\u003elocaltileserver\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_79004ff892fb634039574de525b69e50.addTo(map_2b9ab1557c26a692f8909fb73d2ddfcf);
#
#
#         function geo_json_fc04cc91da5e256f1cd53e7a2b833668_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fc04cc91da5e256f1cd53e7a2b833668_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fc04cc91da5e256f1cd53e7a2b833668_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_fc04cc91da5e256f1cd53e7a2b833668_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_fc04cc91da5e256f1cd53e7a2b833668_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_fc04cc91da5e256f1cd53e7a2b833668.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fc04cc91da5e256f1cd53e7a2b833668_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fc04cc91da5e256f1cd53e7a2b833668 = L.geoJson(null, {
#                 onEachFeature: geo_json_fc04cc91da5e256f1cd53e7a2b833668_onEachFeature,
#
#                 style: geo_json_fc04cc91da5e256f1cd53e7a2b833668_styler,
#                 pointToLayer: geo_json_fc04cc91da5e256f1cd53e7a2b833668_pointToLayer,
#         });
#
#         function geo_json_fc04cc91da5e256f1cd53e7a2b833668_add (data) {
#             geo_json_fc04cc91da5e256f1cd53e7a2b833668
#                 .addData(data);
#         }
#             geo_json_fc04cc91da5e256f1cd53e7a2b833668_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.66

# %%
# add elevation information to each row
import rasterio

#create raster layer for sampling
src = rasterio.open(elevation_file)

# create a list of coordinates for sampling
coord_list = [(x, y) for x, y in zip(filtered_locations['geometry'].x, filtered_locations['geometry'].y)]
# # save the samples back to the dataframe, and choose the first value
filtered_locations["elevation"] = [x[0] for x in src.sample(coord_list)]
filtered_locations.tail()
# Out:
#     OBJECTID CollarID Date_MMDDY Speed_mph Heading          y            x  \
# 189   146823      856  11/8/2008         0      65  40.388416  -105.522908
# 190   146821      856  11/8/2008       2.3     220  40.388241    -105.5224
# 191   146822      856  11/8/2008         0     155  40.387675  -105.521108
# 192    68072      881  11/8/2008         0     315  40.384808  -105.518541
# 193    67981      881  11/2/2008        15      50  40.412425  -105.507125
#
#                         geometry    elevation
# 189  POINT (-105.52291 40.38842)  2320.149414
# 190  POINT (-105.52240 40.38824)  2318.236084
# 191  POINT (-105.52111 40.38768)  2325.695801
# 192  POINT (-105.51854 40.38481)  2347.079102
# 193  POINT (-105.50713 40.41242)  2703.943359

# %%
# Load in the park boundary data (Format GeoJSON)
import json
park_file="data/Rocky_Mountain_National_Park_-_Boundary_Polygon.geojson"
with open(park_file, 'r') as f:
    park_data = json.load(f)

# %%
# create a map with the boundary and elk locations
m = folium.Map([point.y,point.x], zoom_start = 10)

filtered_locations.explore(m=m, marker_type="marker")

folium.GeoJson(park_data,
    style_function=lambda feature:
        { 'color': 'red','opacity': 1, 'dashArray': '9', 'fillOpacity': 0.2, 'weight': 2},
        name="RMNP park boundary"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad79f1d73c365605a635ae1a5228386b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad79f1d73c365605a635ae1a5228386b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad79f1d73c365605a635ae1a5228386b = L.map(
#                 &quot;map_ad79f1d73c365605a635ae1a5228386b&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a441e000823970128156936d9cf89803 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a441e000823970128156936d9cf89803.addTo(map_ad79f1d73c365605a635ae1a5228386b);
#
#
#         function geo_json_1e3f5d8bca6fd13873b06c572bef9393_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1e3f5d8bca6fd13873b06c572bef9393_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1e3f5d8bca6fd13873b06c572bef9393_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_1e3f5d8bca6fd13873b06c572bef9393_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_1e3f5d8bca6fd13873b06c572bef9393_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_1e3f5d8bca6fd13873b06c572bef9393.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1e3f5d8bca6fd13873b06c572bef9393_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1e3f5d8bca6fd13873b06c572bef9393 = L.geoJson(null, {
#                 onEachFeature: geo_json_1e3f5d8bca6fd13873b06c572bef9393_onEachFeature,
#
#                 style: geo_json_1e3f5d8bca6fd13873b06c572bef9393_styler,
#                 pointToLayer: geo_json_1e3f5d8bca6fd13873b06c572bef9393_pointToLayer,
#         });
#
#         function geo_json_1e3f5d8bca6fd13873b06c572bef9393_add (data) {
#             geo_json_1e3f5d8bca6fd13873b06c572bef9393
#                 .addData(data);
#         }
#             geo_json_1e3f5d8bca6fd13873b06c572bef9393_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;elevation&quot;: 3315.504150390625, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;elevation&quot;: 2984.46142578125, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&q

# %%
# Check if locations are in the park polygon

park_polygon: Polygon = shape(park_data["features"][0]["geometry"])

filtered_locations["within_park"] = ""
for index, row in filtered_locations.iterrows():
    marker=Point(row['geometry'].x,row['geometry'].y)
    within=marker.within(park_polygon)
    # row['within_park']=within
    filtered_locations.loc[index, 'within_park'] = within

filtered_locations.head()
# Out:
#   OBJECTID CollarID  Date_MMDDY Speed_mph Heading          y            x  \
# 0   146467   843COW    3/5/2009       9.2     280  40.367308  -105.664583
# 1   146378   843COW  11/16/2008       1.2     345  40.358716  -105.656541
# 2   146816      856   11/7/2008         0     245  40.415933  -105.646525
# 3    68067      881   11/7/2008         0     215  40.410008  -105.644883
# 4   146812      856   11/7/2008         0     305  40.412341  -105.644525
#
#                       geometry    elevation within_park
# 0  POINT (-105.66458 40.36731)  3315.504150        True
# 1  POINT (-105.65654 40.35872)  2984.461426        True
# 2  POINT (-105.64652 40.41593)  2801.393799        True
# 3  POINT (-105.64488 40.41001)  2606.151855        True
# 4  POINT (-105.64453 40.41234)  2633.158691        True

# %%
# create a Web Map Service Layer allowing us to stream in this data from the web without having to download it.
land_cover_wms = folium.WmsTileLayer(
    url='https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2021_Land_Cover_L48/wms',
    layers='NLCD_2021_Land_Cover_L48',
    format='image/png',
    name='NLCD_2021_Land_Cover_L48' # add name to appear in layer dislay control
)

# %%
# create a map with land_cover and filtered locations
m = folium.Map([point.y,point.x], zoom_start = 10)

filtered_locations.explore(m=m, marker_type="marker")

land_cover_wms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65290f72b54b6bb99f0d52d8c80a5036 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65290f72b54b6bb99f0d52d8c80a5036&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65290f72b54b6bb99f0d52d8c80a5036 = L.map(
#                 &quot;map_65290f72b54b6bb99f0d52d8c80a5036&quot;,
#                 {
#                     center: [40.384733209948294, -105.68988068298488],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d507e8d8433c678ad46d8549dad16bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d507e8d8433c678ad46d8549dad16bd.addTo(map_65290f72b54b6bb99f0d52d8c80a5036);
#
#
#         function geo_json_bc59456729de28df6ab4c306638d8c0d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bc59456729de28df6ab4c306638d8c0d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bc59456729de28df6ab4c306638d8c0d_pointToLayer(feature, latlng) {
#             var opts = {};
#
#             let style = geo_json_bc59456729de28df6ab4c306638d8c0d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_bc59456729de28df6ab4c306638d8c0d_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_bc59456729de28df6ab4c306638d8c0d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bc59456729de28df6ab4c306638d8c0d_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bc59456729de28df6ab4c306638d8c0d = L.geoJson(null, {
#                 onEachFeature: geo_json_bc59456729de28df6ab4c306638d8c0d_onEachFeature,
#
#                 style: geo_json_bc59456729de28df6ab4c306638d8c0d_styler,
#                 pointToLayer: geo_json_bc59456729de28df6ab4c306638d8c0d_pointToLayer,
#         });
#
#         function geo_json_bc59456729de28df6ab4c306638d8c0d_add (data) {
#             geo_json_bc59456729de28df6ab4c306638d8c0d
#                 .addData(data);
#         }
#             geo_json_bc59456729de28df6ab4c306638d8c0d_add({&quot;bbox&quot;: [-105.664583, 40.251733, -105.507125, 40.415933], &quot;features&quot;: [{&quot;bbox&quot;: [-105.664583, 40.367308, -105.664583, 40.367308], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.664583, 40.367308], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;3/5/2009&quot;, &quot;Heading&quot;: &quot;280&quot;, &quot;OBJECTID&quot;: &quot;146467&quot;, &quot;Speed_mph&quot;: &quot;9.2&quot;, &quot;elevation&quot;: 3315.504150390625, &quot;within_park&quot;: true, &quot;x&quot;: &quot;-105.664583&quot;, &quot;y&quot;: &quot;40.367308&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.656541, 40.358716, -105.656541, 40.358716], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.656541, 40.358716], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;CollarID&quot;: &quot;843COW&quot;, &quot;Date_MMDDY&quot;: &quot;11/16/2008&quot;, &quot;Heading&quot;: &quot;345&quot;, &quot;OBJECTID&quot;: &quot;146378&quot;, &quot;Speed_mph&quot;: &quot;1.2&quot;, &quot;elevation&quot;: 2984.46142578125, &quot;within_park&quot;: true, &quot;x&quot;: &quot;-105.656541&quot;, &quot;y&quot;: &quot;40.358716&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-105.646525, 40.415933, -105.646525, 40.415933], &quot;geometry&quot;: {&quot;coordinates&quot;: [-105.646525, 40.415933], &

# %%
# add land cover information to each row
# from ipywidgets import IntProgress
# import urllib.request # to make a web request for using a web service
# import time # to allow a timed break between web service request so as to not overwhelm the server

# def get_url_result(url):
#     """
#     Attempts to connect to a webpage
#     :param url: an endpoint
#     :return: the result in json
#     """
#     attempt = 0
#     #print("get_url_result:",url )

#     try:
#         webURL = urllib.request.urlopen(url)
#         data = webURL.read()
#         encoding = webURL.info().get_content_charset('utf-8')
#         return json.loads(data.decode(encoding))


#     except Exception as err:

#         if attempt > 1:
#             print("More than 3 attempts failed to retrieve file. Aborting.")
#             return
#         else:
#             print("Retrieving file failed, waiting 5 sec")
#             print("Message was:", str(err))
#             time.sleep(1)

#     finally:
#         attempt += 1

# #allow showing of progress
# f = IntProgress(min=0, max=filtered_locations.shape[0]) # instantiate the bar with the number of rows for progress
# display(f)


# # create raster layer for sampling
# for index,row in filtered_locations.iterrows():
    
#     lat=filtered_locations.at[index,"y"]
#     lng=filtered_locations.at[index,"x"]
#     lat2=float(filtered_locations.at[index,"y"])+0.00001
#     lng2=float(filtered_locations.at[index,"x"])+0.00001
#     url = "https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2021_Land_Cover_L48/wms?QUERY_LAYERS=NLCD_2021_Land_Cover_L48&INFO_FORMAT=application/json&x=1&y=1&width=2&height=2&bbox={}%2C{}%2C{}%2C{}&crs=EPSG%3A4326&format=image%2Fpng&request=GetFeatureInfo&service=WMS&styles=&transparent=true&version=1.3.0&layers=NLCD_2021_Land_Cover_L48".format(lat,lng,lat2,lng2)

#     f.value = index
#     try:
#         filtered_locations.loc[index, 'land_cover'] = get_url_result(url)['features'][0]['properties']['PALETTE_INDEX']
#     except Exception as err:
#         pass

# %%
# resave the data 
filtered_locations.to_csv(exported_file, index=False)
